# %%
import numpy as np
import scipy as sp
import scipy.special
import matplotlib.pyplot as pyplot

# %%
class neural_network :
    
    def __init__(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        
        # nodes
        self.inodes = input_nodes
        self.hnodes = hidden_nodes
        self.onodes = output_nodes
        
        # learning
        self.lr = learning_rate
        
        # weight
        self.wih = np.random.normal(0.0, pow(self.hnodes, -0.5), (self.hnodes, self.inodes))
        self.who = np.random.normal(0.0, pow(self.onodes, -0.5), (self.onodes, self.hnodes))
        
        # activation function
        self.activation_function = lambda x : sp.special.expit(x)
    
    
    """
        using the given input and target to train the NN
    """
    def train(self, inputs, expect):
        # reconstruct the list
        expect = np.array(expect, ndmin=2).T
        
        #convert input to a 2-D matrix
        inputs = np.array(inputs, ndmin=2).T
        
        #signal into hidden layer
        hidden_inputs = np.dot(self.wih, inputs)

        # siganl emerge from hidden layer
        hidden_outputs = self.activation_function(hidden_inputs)
        
        final_inputs = np.dot(self.who, hidden_outputs)
        final_outputs = self.activation_function(final_inputs)
        
        output_errors = expect - final_outputs
        hidden_errors = np.dot(self.who.T, output_errors)
        
        # print("output_errors:\n",output_errors.shape)
        # print("final_outputs:\n",final_outputs.shape)
        # print("hidden_outputs.T:\n",hidden_outputs.T.shape)
        
        # weights update
        self.who += self.lr * np.dot((output_errors * final_outputs * (1.0 - final_outputs)), 
                                     np.transpose(hidden_outputs))
        
        self.wih += self.lr * np.dot((hidden_errors * hidden_outputs * (1.0 - hidden_outputs)), 
                                     np.transpose(inputs))  
        
        
    """
        trying to find the final output of a NN by given input
    """
    def get_final_output(self, inputs):
        
        #convert input to a 2-D matrix
        inputs = np.array(inputs, ndmin=2).T
        
        #signal into hidden layer
        hidden_inputs = np.dot(self.wih, inputs)

        # siganl emerge from hidden layer
        hidden_outputs = self.activation_function(hidden_inputs)
        
        final_inputs = np.dot(self.who, hidden_outputs)
        final_outputs = self.activation_function(final_inputs)
        
        return final_outputs
    
    """
        use the NN, note that if you want to print out the result, please remove the False
    """
    def query(self, inputs_list, print_img=True):
        
        final_output = self.get_final_output(inputs_list)
        
        
        if(print_img):
            print(final_output)
            pyplot.imshow(inputs_list.reshape(28,28), cmap='Greys', interpolation='None')
        
        return np.argmax(final_output)

# %%
#define nodes
input_nodes = 784
hidden_nodes = 400
output_nodes = 10
learning_rate = 0.1

n = neural_network(input_nodes,hidden_nodes,output_nodes,learning_rate)

# %%
data_file = open("mnist_train.csv", "r")
data_list = data_file.readlines()
data_file.close()

# %%
len(data_list)
# Out:
# 60000

# %%
epochs = 10

for i in range(epochs):
    # asfarray can ture a string int list into array
    for data in data_list:
        image_array = np.asfarray(data.split(",")[1:])
        inputs = image_array / 255.0 * 0.99 + 0.01
        targets = np.zeros(output_nodes) + 0.01
        targets[int(data.split(",")[0])] = 0.99
        n.train(inputs, targets)

# %% [markdown]
# -------
# test blow

# %%
# download this file from https://pjreddie.com/projects/mnist-in-csv/
with open("mnist_test.csv", "r") as f:
    test_sample = f.readlines()

len(test_sample)
# Out:
# 10000

# %%
correct = 0
total = 0
for d in test_sample:
    all_d = d.split(",")
    image_array = np.asfarray(all_d[1:])
    inputs = image_array / 255.0 * 0.99 + 0.01
    
    observe = n.query(inputs, False)
    total += 1
    
    print(total, ": ", "we observe ", observe , ", and we expect " , all_d[0])

    if(observe == int(all_d[0])):
        correct += 1

print("total: ", total, " correct: ", correct, " percentage: ", (correct/total)*100, "%")
# Out:
# 1 :  we observe  7 , and we expect  7
# 2 :  we observe  2 , and we expect  2
# 3 :  we observe  1 , and we expect  1
# 4 :  we observe  0 , and we expect  0
# 5 :  we observe  4 , and we expect  4
# 6 :  we observe  1 , and we expect  1
# 7 :  we observe  4 , and we expect  4
# 8 :  we observe  9 , and we expect  9
# 9 :  we observe  5 , and we expect  5
# 10 :  we observe  9 , and we expect  9
# 11 :  we observe  0 , and we expect  0
# 12 :  we observe  6 , and we expect  6
# 13 :  we observe  9 , and we expect  9
# 14 :  we observe  0 , and we expect  0
# 15 :  we observe  1 , and we expect  1
# 16 :  we observe  5 , and we expect  5
# 17 :  we observe  9 , and we expect  9
# 18 :  we observe  7 , and we expect  7
# 19 :  we observe  3 , and we expect  3
# 20 :  we observe  4 , and we expect  4
# 21 :  we observe  9 , and we expect  9
# 22 :  we observe  6 , and we expect  6
# 23 :  we observe  6 , and we expect  6
# 24 :  we observe  5 , and we expect  5
# 25 :  we observe  4 , and we expect  4
# 26 :  we observe  0 , and we expect  0
# 27 :  we observe  7 , and we expect  7
# 28 :  we observe  4 , and we expect  4
# 29 :  we observe  0 , and we expect  0
# 30 :  we observe  1 , and we expect  1
# 31 :  we observe  3 , and we expect  3
# 32 :  we observe  1 , and we expect  1
# 33 :  we observe  3 , and we expect  3
# 34 :  we observe  4 , and we expect  4
# 35 :  we observe  7 , and we expect  7
# 36 :  we observe  2 , and we expect  2
# 37 :  we observe  7 , and we expect  7
# 38 :  we observe  1 , and we expect  1
# 39 :  we observe  2 , and we expect  2
# 40 :  we observe  1 , and we expect  1
# 41 :  we observe  1 , and we expect  1
# 42 :  we observe  7 , and we expect  7
# 43 :  we observe  4 , and we expect  4
# 44 :  we observe  2 , and we expect  2
# 45 :  we observe  3 , and we expect  3
# 46 :  we observe  5 , and we expect  5
# 47 :  we observe  1 , and we expect  1
# 48 :  we observe  2 , and we expect  2
# 49 :  we observe  4 , and we expect  4
# 50 :  we observe  4 , and we expect  4
# 51 :  we observe  6 , and we expect  6
# 52 :  we observe  3 , and we expect  3
# 53 :  we observe  5 , and we expect  5
# 54 :  we observe  5 , and we expect  5
# 55 :  we observe  6 , and we expect  6
# 56 :  we observe  0 , and we expect  0
# 57 :  we observe  4 , and we expect  4
# 58 :  we observe  1 , and we expect  1
# 59 :  we observe  9 , and we expect  9
# 60 :  we observe  5 , and we expect  5
# 61 :  we observe  7 , and we expect  7
# 62 :  we observe  8 , and we expect  8
# 63 :  we observe  9 , and we expect  9
# 64 :  we observe  3 , and we expect  3
# 65 :  we observe  7 , and we expect  7
# 66 :  we observe  4 , and we expect  4
# 67 :  we observe  6 , and we expect  6
# 68 :  we observe  4 , and we expect  4
# 69 :  we observe  3 , and we expect  3
# 70 :  we observe  0 , and we expect  0
# 71 :  we observe  7 , and we expect  7
# 72 :  we observe  0 , and we expect  0
# 73 :  we observe  2 , and we expect  2
# 74 :  we observe  9 , and we expect  9
# 75 :  we observe  1 , and we expect  1
# 76 :  we observe  7 , and we expect  7
# 77 :  we observe  3 , and we expect  3
# 78 :  we observe  2 , and we expect  2
# 79 :  we observe  9 , and we expect  9
# 80 :  we observe  7 , and we expect  7
# 81 :  we observe  7 , and we expect  7
# 82 :  we observe  6 , and we expect  6
# 83 :  we observe  2 , and we expect  2
# 84 :  we observe  7 , and we expect  7
# 85 :  we observe  8 , and we expect  8
# 86 :  we observe  4 , and we expect  4
# 87 :  we observe  7 , and we expect  7
# 88 :  we observe  3 , and we expect  3
# 89 :  we observe  6 , and we expect  6
# 90 :  we observe  1 , and we expect  1
# 91 :  we observe  3 , and we expect  3
# 92 :  we observe  6 , and we expect  6
# 93 :  we observe  9 , and we expect  9
# 94 :  we observe  3 , and we expect  3
# 95 :  we observe  1 , and we expect  1
# 96 :  we observe  4 , and we expect  4
# 97 :  we observe  1 , and we expect  1
# 98 :  we observe  7 , and we expect  7
# 99 :  we observe  6 , and we expect  6
# 100 :  we observe  9 , and we expect  9
# 101 :  we observe  6 , and we expect  6
# 102 :  we observe  0 , and we expect  0
# 103 :  we observe  5 , and we expect  5
# 104 :  we observe  4 , and we expect  4
# 105 :  we observe  9 , and we expect  9
# 106 :  we observe  9 , and we expect  9
# 107 :  we observe  2 , and we expect  2
# 108 :  we observe  1 , and we expect  1
# 109 :  we observe  9 , and we expect  9
# 110 :  we observe  4 , and we expect  4
# 111 :  we observe  8 , and we expect  8
# 112 :  we observe  7 , and we expect  7
# 113 :  we observe  3 , and we expect  3
# 114 :  we observe  9 , and we expect  9
# 115 :  we observe  7 , and we expect  7
# 116 :  we observe  9 , and we expect  4
# 117 :  we observe  4 , and we expect  4
# 118 :  we observe  4 , and we expect  4
# 119 :  we observe  9 , and we expect  9
# 120 :  we observe  2 , and we expect  2
# 121 :  we observe  5 , and we expect  5
# 122 :  we observe  4 , and we expect  4
# 123 :  we observe  7 , and we expect  7
# 124 :  we observe  6 , and we expect  6
# 125 :  we observe  7 , and we expect  7
# 126 :  we observe  9 , and we expect  9
# 127 :  we observe  0 , and we expect  0
# 128 :  we observe  5 , and we expect  5
# 129 :  we observe  8 , and we expect  8
# 130 :  we observe  5 , and we expect  5
# 131 :  we observe  6 , and we expect  6
# 132 :  we observe  6 , and we expect  6
# 133 :  we observe  5 , and we expect  5
# 134 :  we observe  7 , and we expect  7
# 135 :  we observe  8 , and we expect  8
# 136 :  we observe  1 , and we expect  1
# 137 :  we observe  0 , and we expect  0
# 138 :  we observe  1 , and we expect  1
# 139 :  we observe  6 , and we expect  6
# 140 :  we observe  4 , and we expect  4
# 141 :  we observe  6 , and we expect  6
# 142 :  we observe  7 , and we expect  7
# 143 :  we observe  3 , and we expect  3
# 144 :  we observe  1 , and we expect  1
# 145 :  we observe  7 , and we expect  7
# 146 :  we observe  1 , and we expect  1
# 147 :  we observe  8 , and we expect  8
# 148 :  we observe  2 , and we expect  2
# 149 :  we observe  0 , and we expect  0
# 150 :  we observe  2 , and we expect  2
# 151 :  we observe  9 , and we expect  9
# 152 :  we observe  9 , and we expect  9
# 153 :  we observe  5 , and we expect  5
# 154 :  we observe  5 , and we expect  5
# 155 :  we observe  1 , and we expect  1
# 156 :  we observe  5 , and we expect  5
# 157 :  we observe  6 , and we expect  6
# 158 :  we observe  0 , and we expect  0
# 159 :  we observe  3 , and we expect  3
# 160 :  we observe  4 , and we expect  4
# 161 :  we observe  4 , and we expect  4
# 162 :  we observe  6 , and we expect  6
# 163 :  we observe  5 , and we expect  5
# 164 :  we observe  4 , and we expect  4
# 165 :  we observe  6 , and we expect  6
# 166 :  we observe  5 , and we expect  5
# 167 :  we observe  4 , and we expect  4
# 168 :  we observe  5 , and we expect  5
# 169 :  we observe  1 , and we expect  1
# 170 :  we observe  4 , and we expect  4
# 171 :  we observe  4 , and we expect  4
# 172 :  we observe  7 , and we expect  7
# 173 :  we observe  2 , and we expect  2
# 174 :  we observe  3 , and we expect  3
# 175 :  we observe  2 , and we expect  2
# 176 :  we observe  7 , and we expect  7
# 177 :  we observe  1 , and we expect  1
# 178 :  we observe  8 , and we expect  8
# 179 :  we observe  1 , and we expect  1
# 180 :  we observe  8 , and we expect  8
# 181 :  we observe  1 , and we expect  1
# 182 :  we observe  8 , and we expect  8
# 183 :  we observe  5 , and we expect  5
# 184 :  we observe  0 , and we expect  0
# 185 :  we observe  8 , and we expect  8
# 186 :  we observe  9 , and we expect  9
# 187 :  we observe  2 , and we expect  2
# 188 :  we observe  5 , and we expect  5
# 189 :  we observe  0 , and we expect  0
# 190 :  we observe  1 , and we expect  1
# 191 :  we observe  1 , and we expect  1
# 192 :  we observe  1 , and we expect  1
# 193 :  we observe  0 , and we expect  0
# 194 :  we observe  9 , and we expect  9
# 195 :  we observe  0 , and we expect  0
# 196 :  we observe  3 , and we expect  3
# 197 :  we observe  1 , and we expect  1
# 198 :  we observe  6 , and we expect  6
# 199 :  we observe  4 , and we expect  4
# 200 :  we observe  2 , and we expect  2
# 201 :  we observe  3 , and we expect  3
# 202 :  we observe  6 , and we expect  6
# 203 :  we observe  1 , and we expect  1
# 204 :  we observe  1 , and we expect  1
# 205 :  we observe  1 , and we expect  1
# 206 :  we observe  3 , and we expect  3
# 207 :  we observe  9 , and we expect  9
# 208 :  we observe  5 , and we expect  5
# 209 :  we observe  2 , and we expect  2
# 210 :  we observe  9 , and we expect  9
# 211 :  we observe  4 , and we expect  4
# 212 :  we observe  5 , and we expect  5
# 213 :  we observe  9 , and we expect  9
# 214 :  we observe  3 , and we expect  3
# 215 :  we observe  9 , and we expect  9
# 216 :  we observe  0 , and we expect  0
# 217 :  we observe  3 , and we expect  3
# 218 :  we observe  5 , and we expect  6
# 219 :  we observe  5 , and we expect  5
# 220 :  we observe  5 , and we expect  5
# 221 :  we observe  7 , and we expect  7
# 222 :  we observe  2 , and we expect  2
# 223 :  we observe  2 , and we expect  2
# 224 :  we observe  7 , and we expect  7
# 225 :  we observe  1 , and we expect  1
# 226 :  we observe  2 , and we expect  2
# 227 :  we observe  8 , and we expect  8
# 228 :  we observe  4 , and we expect  4
# 229 :  we observe  1 , and we expect  1
# 230 :  we observe  7 , and we expect  7
# 231 :  we observe  3 , and we expect  3
# 232 :  we observe  3 , and we expect  3
# 233 :  we observe  8 , and we expect  8
# 234 :  we observe  8 , and we expect  8
# 235 :  we observe  7 , and we expect  7
# 236 :  we observe  9 , and we expect  9
# 237 :  we observe  2 , and we expect  2
# 238 :  we observe  2 , and we expect  2
# 239 :  we observe  4 , and we expect  4
# 240 :  we observe  1 , and we expect  1
# 241 :  we observe  5 , and we expect  5
# 242 :  we observe  9 , and we expect  9
# 243 :  we observe  8 , and we expect  8
# 244 :  we observe  7 , and we expect  7
# 245 :  we observe  2 , and we expect  2
# 246 :  we observe  3 , and we expect  3
# 247 :  we observe  0 , and we expect  0
# 248 :  we observe  2 , and we expect  4
# 249 :  we observe  4 , and we expect  4
# 250 :  we observe  2 , and we expect  2
# 251 :  we observe  4 , and we expect  4
# 252 :  we observe  1 , and we expect  1
# 253 :  we observe  9 , and we expect  9
# 254 :  we observe  5 , and we expect  5
# 255 :  we observe  7 , and we expect  7
# 256 :  we observe  7 , and we expect  7
# 257 :  we observe  2 , and we expect  2
# 258 :  we observe  8 , and we expect  8
# 259 :  we observe  2 , and we expect  2
# 260 :  we observe  0 , and we expect  6
# 261 :  we observe  8 , and we expect  8
# 262 :  we observe  5 , and we expect  5
# 263 :  we observe  7 , and we expect  7
# 264 :  we observe  7 , and we expect  7
# 265 :  we observe  9 , and we expect  9
# 266 :  we observe  1 , and we expect  1
# 267 :  we observe  8 , and we expect  8
# 268 :  we observe  1 , and we expect  1
# 269 :  we observe  8 , and we expect  8
# 270 :  we observe  0 , and we expect  0
# 271 :  we observe  3 , and we expect  3
# 272 :  we observe  0 , and we expect  0
# 273 :  we observe  1 , and we expect  1
# 274 :  we observe  9 , and we expect  9
# 275 :  we observe  9 , and we expect  9
# 276 :  we observe  4 , and we expect  4
# 277 :  we observe  1 , and we expect  1
# 278 :  we observe  8 , and we expect  8
# 279 :  we observe  2 , and we expect  2
# 280 :  we observe  1 , and we expect  1
# 281 :  we observe  2 , and we expect  2
# 282 :  we observe  9 , and we expect  9
# 283 :  we observe  7 , and we expect  7
# 284 :  we observe  5 , and we expect  5
# 285 :  we observe  9 , and we expect  9
# 286 :  we observe  2 , and we expect  2
# 287 :  we observe  6 , and we expect  6
# 288 :  we observe  4 , and we expect  4
# 289 :  we observe  1 , and we expect  1
# 290 :  we observe  5 , and we expect  5
# 291 :  we observe  8 , and we expect  8
# 292 :  we observe  2 , and we expect  2
# 293 :  we observe  9 , and we expect  9
# 294 :  we observe  2 , and we expect  2
# 295 :  we observe  0 , and we expect  0
# 296 :  we observe  4 , and we expect  4
# 297 :  we observe  0 , and we expect  0
# 298 :  we observe  0 , and we expect  0
# 299 :  we observe  2 , and we expect  2
# 300 :  we observe  8 , and we expect  8
# 301 :  we observe  4 , and we expect  4
# 302 :  we observe  7 , and we expect  7
# 303 :  we observe  1 , and we expect  1
# 304 :  we observe  2 , and we expect  2
# 305 :  we observe  4 , and we expect  4
# 306 :  we observe  0 , and we expect  0
# 307 :  we observe  2 , and we expect  2
# 308 :  we observe  7 , and we expect  7
# 309 :  we observe  4 , and we expect  4
# 310 :  we observe  3 , and we expect  3
# 311 :  we observe  3 , and we expect  3
# 312 :  we observe  0 , and we expect  0
# 313 :  we observe  0 , and we expect  0
# 314 :  we observe  3 , and we expect  3
# 315 :  we observe  1 , and we expect  1
# 316 :  we observe  9 , and we expect  9
# 317 :  we observe  6 , and we expect  6
# 318 :  we observe  5 , and we expect  5
# 319 :  we observe  2 , and we expect  2
# 320 :  we observe  5 , and we expect  5
# 321 :  we observe  9 , and we expect  9
# 322 :  we observe  7 , and we expect  2
# 323 :  we observe  9 , and we expect  9
# 324 :  we observe  3 , and we expect  3
# 325 :  we observe  0 , and we expect  0
# 326 :  we observe  4 , and we expect  4
# 327 :  we observe  2 , and we expect  2
# 328 :  we observe  0 , and we expect  0
# 329 :  we observe  7 , and we expect  7
# 330 :  we observe  1 , and we expect  1
# 331 :  we observe  1 , and we expect  1
# 332 :  we observe  2 , and we expect  2
# 333 :  we observe  1 , and we expect  1
# 334 :  we observe  5 , and we expect  5
# 335 :  we observe  3 , and we expect  3
# 336 :  we observe  3 , and we expect  3
# 337 :  we observe  9 , and we expect  9
# 338 :  we observe  7 , and we expect  7
# 339 :  we observe  8 , and we expect  8
# 340 :  we observe  6 , and we expect  6
# 341 :  we observe  3 , and we expect  5
# 342 :  we observe  6 , and we expect  6
# 343 :  we observe  1 , and we expect  1
# 344 :  we observe  3 , and we expect  3
# 345 :  we observe  8 , and we expect  8
# 346 :  we observe  1 , and we expect  1
# 347 :  we observe  0 , and we expect  0
# 348 :  we observe  5 , and we expect  5
# 349 :  we observe  1 , and we expect  1
# 350 :  we observe  3 , and we expect  3
# 351 :  we observe  1 , and we expect  1
# 352 :  we observe  5 , and we expect  5
# 353 :  we observe  5 , and we expect  5
# 354 :  we observe  6 , and we expect  6
# 355 :  we observe  1 , and we expect  1
# 356 :  we observe  8 , and we expect  8
# 357 :  we observe  5 , and we expect  5
# 358 :  we observe  1 , and we expect  1
# 359 :  we observe  7 , and we expect  7
# 360 :  we observe  9 , and we expect  9
# 361 :  we observe  4 , and we expect  4
# 362 :  we observe  6 , and we expect  6
# 363 :  we observe  2 , and we expect  2
# 364 :  we observe  2 , and we expect  2
# 365 :  we observe  5 , and we expect  5
# 366 :  we observe  0 , and we expect  0
# 367 :  we observe  6 , and we expect  6
# 368 :  we observe  5 , and we expect  5
# 369 :  we observe  6 , and we expect  6
# 370 :  we observe  3 , and we expect  3
# 371 :  we observe  7 , and we expect  7
# 372 :  we observe  2 , and we expect  2
# 373 :  we observe  0 , and we expect  0
# 374 :  we observe  8 , and we expect  8
# 375 :  we observe  8 , and we expect  8
# 376 :  we observe  5 , and we expect  5
# 377 :  we observe  4 , and we expect  4
# 378 :  we observe  1 , and we expect  1
# 379 :  we observe  1 , and we expect  1
# 380 :  we observe  4 , and we expect  4
# 381 :  we observe  0 , and we expect  0
# 382 :  we observe  7 , and we expect  3
# 383 :  we observe  3 , and we expect  3
# 384 :  we observe  7 , and we expect  7
# 385 :  we observe  6 , and we expect  6
# 386 :  we observe  1 , and we expect  1
# 387 :  we observe  6 , and we expect  6
# 388 :  we observe  2 , and we expect  2
# 389 :  we observe  1 , and we expect  1
# 390 :  we observe  9 , and we expect  9
# 391 :  we observe  2 , and we expect  2
# 392 :  we observe  8 , and we expect  8
# 393 :  we observe  6 , and we expect  6
# 394 :  we observe  1 , and we expect  1
# 395 :  we observe  9 , and we expect  9
# 396 :  we observe  5 , and we expect  5
# 397 :  we observe  2 , and we expect  2
# 398 :  we observe  5 , and we expect  5
# 399 :  we observe  4 , and we expect  4
# 400 :  we observe  4 , and we expect  4
# 401 :  we observe  2 , and we expect  2
# 402 :  we observe  8 , and we expect  8
# 403 :  we observe  3 , and we expect  3
# 404 :  we observe  8 , and we expect  8
# 405 :  we observe  2 , and we expect  2
# 406 :  we observe  4 , and we expect  4
# 407 :  we observe  5 , and we expect  5
# 408 :  we observe  0 , and we expect  0
# 409 :  we observe  3 , and we expect  3
# 410 :  we observe  1 , and we expect  1
# 411 :  we observe  7 , and we expect  7
# 412 :  we observe  7 , and we expect  7
# 413 :  we observe  5 , and we expect  5
# 414 :  we observe  7 , and we expect  7
# 415 :  we observe  9 , and we expect  9
# 416 :  we observe  7 , and we expect  7
# 417 :  we observe  1 , and we expect  1
# 418 :  we observe  9 , and we expect  9
# 419 :  we observe  2 , and we expect  2
# 420 :  we observe  1 , and we expect  1
# 421 :  we observe  4 , and we expect  4
# 422 :  we observe  2 , and we expect  2
# 423 :  we observe  9 , and we expect  9
# 424 :  we observe  2 , and we expect  2
# 425 :  we observe  0 , and we expect  0
# 426 :  we observe  4 , and we expect  4
# 427 :  we observe  9 , and we expect  9
# 428 :  we observe  1 , and we expect  1
# 429 :  we observe  4 , and we expect  4
# 430 :  we observe  8 , and we expect  8
# 431 :  we observe  1 , and we expect  1
# 432 :  we observe  8 , and we expect  8
# 433 :  we observe  4 , and we expect  4
# 434 :  we observe  5 , and we expect  5
# 435 :  we observe  9 , and we expect  9
# 436 :  we observe  8 , and we expect  8
# 437 :  we observe  8 , and we expect  8
# 438 :  we observe  3 , and we expect  3
# 439 :  we observe  7 , and we expect  7
# 440 :  we observe  6 , and we expect  6
# 441 :  we observe  0 , and we expect  0
# 442 :  we observe  0 , and we expect  0
# 443 :  we observe  3 , and we expect  3
# 444 :  we observe  0 , and we expect  0
# 445 :  we observe  2 , and we expect  2
# 446 :  we observe  0 , and we expect  6
# 447 :  we observe  6 , and we expect  6
# 448 :  we observe  4 , and we expect  4
# 449 :  we observe  8 , and we expect  9
# 450 :  we observe  5 , and we expect  3
# 451 :  we observe  3 , and we expect  3
# 452 :  we observe  3 , and we expect  3
# 453 :  we observe  2 , and we expect  2
# 454 :  we observe  3 , and we expect  3
# 455 :  we observe  9 , and we expect  9
# 456 :  we observe  1 , and we expect  1
# 457 :  we observe  2 , and we expect  2
# 458 :  we observe  6 , and we expect  6
# 459 :  we observe  8 , and we expect  8
# 460 :  we observe  0 , and we expect  0
# 461 :  we observe  5 , and we expect  5
# 462 :  we observe  6 , and we expect  6
# 463 :  we observe  6 , and we expect  6
# 464 :  we observe  6 , and we expect  6
# 465 :  we observe  3 , and we expect  3
# 466 :  we observe  8 , and we expect  8
# 467 :  we observe  8 , and we expect  8
# 468 :  we observe  2 , and we expect  2
# 469 :  we observe  3 , and we expect  7
# 470 :  we observe  5 , and we expect  5
# 471 :  we observe  8 , and we expect  8
# 472 :  we observe  9 , and we expect  9
# 473 :  we observe  6 , and we expect  6
# 474 :  we observe  1 , and we expect  1
# 475 :  we observe  8 , and we expect  8
# 476 :  we observe  4 , and we expect  4
# 477 :  we observe  1 , and we expect  1
# 478 :  we observe  2 , and we expect  2
# 479 :  we observe  5 , and we expect  5
# 480 :  we observe  9 , and we expect  9
# 481 :  we observe  1 , and we expect  1
# 482 :  we observe  9 , and we expect  9
# 483 :  we observe  7 , and we expect  7
# 484 :  we observe  5 , and we expect  5
# 485 :  we observe  4 , and we expect  4
# 486 :  we observe  0 , and we expect  0
# 487 :  we observe  8 , and we expect  8
# 488 :  we observe  9 , and we expect  9
# 489 :  we observe  9 , and we expect  9
# 490 :  we observe  1 , and we expect  1
# 491 :  we observe  0 , and we expect  0
# 492 :  we observe  5 , and we expect  5
# 493 :  we observe  2 , and we expect  2
# 494 :  we observe  3 , and we expect  3
# 495 :  we observe  7 , and we expect  7
# 496 :  we observe  9 , and we expect  8
# 497 :  we observe  9 , and we expect  9
# 498 :  we observe  4 , and we expect  4
# 499 :  we observe  0 , and we expect  0
# 500 :  we observe  6 , and we expect  6
# 501 :  we observe  3 , and we expect  3
# 502 :  we observe  9 , and we expect  9
# 503 :  we observe  5 , and we expect  5
# 504 :  we observe  2 , and we expect  2
# 505 :  we observe  1 , and we expect  1
# 506 :  we observe  3 , and we expect  3
# 507 :  we observe  1 , and we expect  1
# 508 :  we observe  3 , and we expect  3
# 509 :  we observe  6 , and we expect  6
# 510 :  we observe  5 , and we expect  5
# 511 :  we observe  7 , and we expect  7
# 512 :  we observe  4 , and we expect  4
# 513 :  we observe  2 , and we expect  2
# 514 :  we observe  2 , and we expect  2
# 515 :  we observe  6 , and we expect  6
# 516 :  we observe  3 , and we expect  3
# 517 :  we observe  2 , and we expect  2
# 518 :  we observe  6 , and we expect  6
# 519 :  we observe  5 , and we expect  5
# 520 :  we observe  4 , and we expect  4
# 521 :  we observe  8 , and we expect  8
# 522 :  we observe  9 , and we expect  9
# 523 :  we observe  7 , and we expect  7
# 524 :  we observe  1 , and we expect  1
# 525 :  we observe  3 , and we expect  3
# 526 :  we observe  0 , and we expect  0
# 527 :  we observe  3 , and we expect  3
# 528 :  we observe  8 , and we expect  8
# 529 :  we observe  3 , and we expect  3
# 530 :  we observe  1 , and we expect  1
# 531 :  we observe  9 , and we expect  9
# 532 :  we observe  3 , and we expect  3
# 533 :  we observe  4 , and we expect  4
# 534 :  we observe  4 , and we expect  4
# 535 :  we observe  6 , and we expect  6
# 536 :  we observe  4 , and we expect  4
# 537 :  we observe  2 , and we expect  2
# 538 :  we observe  1 , and we expect  1
# 539 :  we observe  8 , and we expect  8
# 540 :  we observe  2 , and we expect  2
# 541 :  we observe  5 , and we expect  5
# 542 :  we observe  4 , and we expect  4
# 543 :  we observe  8 , and we expect  8
# 544 :  we observe  8 , and we expect  8
# 545 :  we observe  4 , and we expect  4
# 546 :  we observe  0 , and we expect  0
# 547 :  we observe  0 , and we expect  0
# 548 :  we observe  2 , and we expect  2
# 549 :  we observe  3 , and we expect  3
# 550 :  we observe  2 , and we expect  2
# 551 :  we observe  7 , and we expect  7
# 552 :  we observe  7 , and we expect  7
# 553 :  we observe  0 , and we expect  0
# 554 :  we observe  8 , and we expect  8
# 555 :  we observe  7 , and we expect  7
# 556 :  we observe  4 , and we expect  4
# 557 :  we observe  4 , and we expect  4
# 558 :  we observe  7 , and we expect  7
# 559 :  we observe  9 , and we expect  9
# 560 :  we observe  6 , and we expect  6
# 561 :  we observe  9 , and we expect  9
# 562 :  we observe  0 , and we expect  0
# 563 :  we observe  9 , and we expect  9
# 564 :  we observe  8 , and we expect  8
# 565 :  we observe  0 , and we expect  0
# 566 :  we observe  4 , and we expect  4
# 567 :  we observe  6 , and we expect  6
# 568 :  we observe  0 , and we expect  0
# 569 :  we observe  6 , and we expect  6
# 570 :  we observe  3 , and we expect  3
# 571 :  we observe  5 , and we expect  5
# 572 :  we observe  4 , and we expect  4
# 573 :  we observe  8 , and we expect  8
# 574 :  we observe  3 , and we expect  3
# 575 :  we observe  3 , and we expect  3
# 576 :  we observe  9 , and we expect  9
# 577 :  we observe  3 , and we expect  3
# 578 :  we observe  3 , and we expect  3
# 579 :  we observe  3 , and we expect  3
# 580 :  we observe  7 , and we expect  7
# 581 :  we observe  8 , and we expect  8
# 582 :  we observe  0 , and we expect  0
# 583 :  we observe  2 , and we expect  8
# 584 :  we observe  2 , and we expect  2
# 585 :  we observe  1 , and we expect  1
# 586 :  we observe  7 , and we expect  7
# 587 :  we observe  0 , and we expect  0
# 588 :  we observe  6 , and we expect  6
# 589 :  we observe  5 , and we expect  5
# 590 :  we observe  4 , and we expect  4
# 591 :  we observe  3 , and we expect  3
# 592 :  we observe  8 , and we expect  8
# 593 :  we observe  0 , and we expect  0
# 594 :  we observe  9 , and we expect  9
# 595 :  we observe  6 , and we expect  6
# 596 :  we observe  3 , and we expect  3
# 597 :  we observe  8 , and we expect  8
# 598 :  we observe  0 , and we expect  0
# 599 :  we observe  9 , and we expect  9
# 600 :  we observe  9 , and we expect  9
# 601 :  we observe  6 , and we expect  6
# 602 :  we observe  8 , and we expect  8
# 603 :  we observe  6 , and we expect  6
# 604 :  we observe  8 , and we expect  8
# 605 :  we observe  5 , and we expect  5
# 606 :  we observe  7 , and we expect  7
# 607 :  we observe  8 , and we expect  8
# 608 :  we observe  6 , and we expect  6
# 609 :  we observe  0 , and we expect  0
# 610 :  we observe  2 , and we expect  2
# 611 :  we observe  4 , and we expect  4
# 612 :  we observe  0 , and we expect  0
# 613 :  we observe  2 , and we expect  2
# 614 :  we observe  2 , and we expect  2
# 615 :  we observe  3 , and we expect  3
# 616 :  we observe  1 , and we expect  1
# 617 :  we observe  9 , and we expect  9
# 618 :  we observe  7 , and we expect  7
# 619 :  we observe  5 , and we expect  5
# 620 :  we observe  8 , and we expect  1
# 621 :  we observe  0 , and we expect  0
# 622 :  we observe  8 , and we expect  8
# 623 :  we observe  4 , and we expect  4
# 624 :  we observe  6 , and we expect  6
# 625 :  we observe  2 , and we expect  2
# 626 :  we observe  6 , and we expect  6
# 627 :  we observe  7 , and we expect  7
# 628 :  we observe  9 , and we expect  9
# 629 :  we observe  3 , and we expect  3
# 630 :  we observe  2 , and we expect  2
# 631 :  we observe  9 , and we expect  9
# 632 :  we observe  8 , and we expect  8
# 633 :  we observe  2 , and we expect  2
# 634 :  we observe  2 , and we expect  2
# 635 :  we observe  9 , and we expect  9
# 636 :  we observe  2 , and we expect  2
# 637 :  we observe  7 , and we expect  7
# 638 :  we observe  3 , and we expect  3
# 639 :  we observe  5 , and we expect  5
# 640 :  we observe  9 , and we expect  9
# 641 :  we observe  1 , and we expect  1
# 642 :  we observe  8 , and we expect  8
# 643 :  we observe  0 , and we expect  0
# 644 :  we observe  2 , and we expect  2
# 645 :  we observe  0 , and we expect  0
# 646 :  we observe  5 , and we expect  5
# 647 :  we observe  2 , and we expect  2
# 648 :  we observe  1 , and we expect  1
# 649 :  we observe  3 , and we expect  3
# 650 :  we observe  7 , and we expect  7
# 651 :  we observe  6 , and we expect  6
# 652 :  we observe  7 , and we expect  7
# 653 :  we observe  1 , and we expect  1
# 654 :  we observe  2 , and we expect  2
# 655 :  we observe  5 , and we expect  5
# 656 :  we observe  8 , and we expect  8
# 657 :  we observe  0 , and we expect  0
# 658 :  we observe  3 , and we expect  3
# 659 :  we observe  7 , and we expect  7
# 660 :  we observe  8 , and we expect  2
# 661 :  we observe  4 , and we expect  4
# 662 :  we observe  0 , and we expect  0
# 663 :  we observe  9 , and we expect  9
# 664 :  we observe  1 , and we expect  1
# 665 :  we observe  8 , and we expect  8
# 666 :  we observe  6 , and we expect  6
# 667 :  we observe  7 , and we expect  7
# 668 :  we observe  7 , and we expect  7
# 669 :  we observe  4 , and we expect  4
# 670 :  we observe  3 , and we expect  3
# 671 :  we observe  4 , and we expect  4
# 672 :  we observe  9 , and we expect  9
# 673 :  we observe  1 , and we expect  1
# 674 :  we observe  9 , and we expect  9
# 675 :  we observe  5 , and we expect  5
# 676 :  we observe  1 , and we expect  1
# 677 :  we observe  7 , and we expect  7
# 678 :  we observe  3 , and we expect  3
# 679 :  we observe  9 , and we expect  9
# 680 :  we observe  7 , and we expect  7
# 681 :  we observe  6 , and we expect  6
# 682 :  we observe  9 , and we expect  9
# 683 :  we observe  1 , and we expect  1
# 684 :  we observe  3 , and we expect  3
# 685 :  we observe  3 , and we expect  7
# 686 :  we observe  8 , and we expect  8
# 687 :  we observe  3 , and we expect  3
# 688 :  we observe  3 , and we expect  3
# 689 :  we observe  6 , and we expect  6
# 690 :  we observe  7 , and we expect  7
# 691 :  we observe  2 , and we expect  2
# 692 :  we observe  4 , and we expect  8
# 693 :  we observe  5 , and we expect  5
# 694 :  we observe  8 , and we expect  8
# 695 :  we observe  5 , and we expect  5
# 696 :  we observe  1 , and we expect  1
# 697 :  we observe  1 , and we expect  1
# 698 :  we observe  4 , and we expect  4
# 699 :  we observe  4 , and we expect  4
# 700 :  we observe  3 , and we expect  3
# 701 :  we observe  1 , and we expect  1
# 702 :  we observe  0 , and we expect  0
# 703 :  we observe  7 , and we expect  7
# 704 :  we observe  7 , and we expect  7
# 705 :  we observe  0 , and we expect  0
# 706 :  we observe  7 , and we expect  7
# 707 :  we observe  9 , and we expect  9
# 708 :  we observe  9 , and we expect  4
# 709 :  we observe  4 , and we expect  4
# 710 :  we observe  8 , and we expect  8
# 711 :  we observe  5 , and we expect  5
# 712 :  we observe  5 , and we expect  5
# 713 :  we observe  4 , and we expect  4
# 714 :  we observe  0 , and we expect  0
# 715 :  we observe  8 , and we expect  8
# 716 :  we observe  2 , and we expect  2
# 717 :  we observe  1 , and we expect  1
# 718 :  we observe  0 , and we expect  0
# 719 :  we observe  8 , and we expect  8
# 720 :  we observe  4 , and we expect  4
# 721 :  we observe  8 , and we expect  5
# 722 :  we observe  0 , and we expect  0
# 723 :  we observe  4 , and we expect  4
# 724 :  we observe  0 , and we expect  0
# 725 :  we observe  6 , and we expect  6
# 726 :  we observe  1 , and we expect  1
# 727 :  we observe  7 , and we expect  7
# 728 :  we observe  3 , and we expect  3
# 729 :  we observe  2 , and we expect  2
# 730 :  we observe  6 , and we expect  6
# 731 :  we observe  7 , and we expect  7
# 732 :  we observe  2 , and we expect  2
# 733 :  we observe  6 , and we expect  6
# 734 :  we observe  9 , and we expect  9
# 735 :  we observe  3 , and we expect  3
# 736 :  we observe  1 , and we expect  1
# 737 :  we observe  4 , and we expect  4
# 738 :  we observe  6 , and we expect  6
# 739 :  we observe  2 , and we expect  2
# 740 :  we observe  5 , and we expect  5
# 741 :  we observe  4 , and we expect  4
# 742 :  we observe  2 , and we expect  2
# 743 :  we observe  0 , and we expect  0
# 744 :  we observe  6 , and we expect  6
# 745 :  we observe  2 , and we expect  2
# 746 :  we observe  1 , and we expect  1
# 747 :  we observe  7 , and we expect  7
# 748 :  we observe  3 , and we expect  3
# 749 :  we observe  4 , and we expect  4
# 750 :  we observe  1 , and we expect  1
# 751 :  we observe  0 , and we expect  0
# 752 :  we observe  5 , and we expect  5
# 753 :  we observe  4 , and we expect  4
# 754 :  we observe  3 , and we expect  3
# 755 :  we observe  1 , and we expect  1
# 756 :  we observe  1 , and we expect  1
# 757 :  we observe  7 , and we expect  7
# 758 :  we observe  4 , and we expect  4
# 759 :  we observe  9 , and we expect  9
# 760 :  we observe  9 , and we expect  9
# 761 :  we observe  4 , and we expect  4
# 762 :  we observe  8 , and we expect  8
# 763 :  we observe  4 , and we expect  4
# 764 :  we observe  0 , and we expect  0
# 765 :  we observe  2 , and we expect  2
# 766 :  we observe  4 , and we expect  4
# 767 :  we observe  5 , and we expect  5
# 768 :  we observe  1 , and we expect  1
# 769 :  we observe  1 , and we expect  1
# 770 :  we observe  6 , and we expect  6
# 771 :  we observe  4 , and we expect  4
# 772 :  we observe  7 , and we expect  7
# 773 :  we observe  1 , and we expect  1
# 774 :  we observe  9 , and we expect  9
# 775 :  we observe  4 , and we expect  4
# 776 :  we observe  2 , and we expect  2
# 777 :  we observe  4 , and we expect  4
# 778 :  we observe  1 , and we expect  1
# 779 :  we observe  5 , and we expect  5
# 780 :  we observe  5 , and we expect  5
# 781 :  we observe  3 , and we expect  3
# 782 :  we observe  8 , and we expect  8
# 783 :  we observe  3 , and we expect  3
# 784 :  we observe  1 , and we expect  1
# 785 :  we observe  4 , and we expect  4
# 786 :  we observe  5 , and we expect  5
# 787 :  we observe  6 , and we expect  6
# 788 :  we observe  8 , and we expect  8
# 789 :  we observe  9 , and we expect  9
# 790 :  we observe  4 , and we expect  4
# 791 :  we observe  1 , and we expect  1
# 792 :  we observe  5 , and we expect  5
# 793 :  we observe  3 , and we expect  3
# 794 :  we observe  8 , and we expect  8
# 795 :  we observe  0 , and we expect  0
# 796 :  we observe  3 , and we expect  3
# 797 :  we observe  2 , and we expect  2
# 798 :  we observe  5 , and we expect  5
# 799 :  we observe  1 , and we expect  1
# 800 :  we observe  2 , and we expect  2
# 801 :  we observe  8 , and we expect  8
# 802 :  we observe  3 , and we expect  3
# 803 :  we observe  4 , and we expect  4
# 804 :  we observe  4 , and we expect  4
# 805 :  we observe  0 , and we expect  0
# 806 :  we observe  8 , and we expect  8
# 807 :  we observe  8 , and we expect  8
# 808 :  we observe  3 , and we expect  3
# 809 :  we observe  3 , and we expect  3
# 810 :  we observe  1 , and we expect  1
# 811 :  we observe  7 , and we expect  7
# 812 :  we observe  3 , and we expect  3
# 813 :  we observe  5 , and we expect  5
# 814 :  we observe  9 , and we expect  9
# 815 :  we observe  6 , and we expect  6
# 816 :  we observe  3 , and we expect  3
# 817 :  we observe  2 , and we expect  2
# 818 :  we observe  6 , and we expect  6
# 819 :  we observe  1 , and we expect  1
# 820 :  we observe  3 , and we expect  3
# 821 :  we observe  6 , and we expect  6
# 822 :  we observe  0 , and we expect  0
# 823 :  we observe  7 , and we expect  7
# 824 :  we observe  2 , and we expect  2
# 825 :  we observe  1 , and we expect  1
# 826 :  we observe  7 , and we expect  7
# 827 :  we observe  1 , and we expect  1
# 828 :  we observe  4 , and we expect  4
# 829 :  we observe  2 , and we expect  2
# 830 :  we observe  4 , and we expect  4
# 831 :  we observe  2 , and we expect  2
# 832 :  we observe  1 , and we expect  1
# 833 :  we observe  7 , and we expect  7
# 834 :  we observe  9 , and we expect  9
# 835 :  we observe  6 , and we expect  6
# 836 :  we observe  1 , and we expect  1
# 837 :  we observe  1 , and we expect  1
# 838 :  we observe  2 , and we expect  2
# 839 :  we observe  4 , and we expect  4
# 840 :  we observe  3 , and we expect  8
# 841 :  we observe  1 , and we expect  1
# 842 :  we observe  7 , and we expect  7
# 843 :  we observe  7 , and we expect  7
# 844 :  we observe  4 , and we expect  4
# 845 :  we observe  8 , and we expect  8
# 846 :  we observe  0 , and we expect  0
# 847 :  we observe  7 , and we expect  7
# 848 :  we observe  3 , and we expect  3
# 849 :  we observe  1 , and we expect  1
# 850 :  we observe  3 , and we expect  3
# 851 :  we observe  1 , and we expect  1
# 852 :  we observe  0 , and we expect  0
# 853 :  we observe  7 , and we expect  7
# 854 :  we observe  7 , and we expect  7
# 855 :  we observe  0 , and we expect  0
# 856 :  we observe  3 , and we expect  3
# 857 :  we observe  5 , and we expect  5
# 858 :  we observe  5 , and we expect  5
# 859 :  we observe  2 , and we expect  2
# 860 :  we observe  7 , and we expect  7
# 861 :  we observe  6 , and we expect  6
# 862 :  we observe  6 , and we expect  6
# 863 :  we observe  9 , and we expect  9
# 864 :  we observe  2 , and we expect  2
# 865 :  we observe  8 , and we expect  8
# 866 :  we observe  3 , and we expect  3
# 867 :  we observe  5 , and we expect  5
# 868 :  we observe  2 , and we expect  2
# 869 :  we observe  2 , and we expect  2
# 870 :  we observe  5 , and we expect  5
# 871 :  we observe  6 , and we expect  6
# 872 :  we observe  0 , and we expect  0
# 873 :  we observe  8 , and we expect  8
# 874 :  we observe  2 , and we expect  2
# 875 :  we observe  9 , and we expect  9
# 876 :  we observe  2 , and we expect  2
# 877 :  we observe  8 , and we expect  8
# 878 :  we observe  8 , and we expect  8
# 879 :  we observe  8 , and we expect  8
# 880 :  we observe  8 , and we expect  8
# 881 :  we observe  7 , and we expect  7
# 882 :  we observe  4 , and we expect  4
# 883 :  we observe  4 , and we expect  9
# 884 :  we observe  3 , and we expect  3
# 885 :  we observe  0 , and we expect  0
# 886 :  we observe  6 , and we expect  6
# 887 :  we observe  6 , and we expect  6
# 888 :  we observe  3 , and we expect  3
# 889 :  we observe  2 , and we expect  2
# 890 :  we observe  1 , and we expect  1
# 891 :  we observe  3 , and we expect  3
# 892 :  we observe  2 , and we expect  2
# 893 :  we observe  2 , and we expect  2
# 894 :  we observe  9 , and we expect  9
# 895 :  we observe  3 , and we expect  3
# 896 :  we observe  0 , and we expect  0
# 897 :  we observe  0 , and we expect  0
# 898 :  we observe  5 , and we expect  5
# 899 :  we observe  7 , and we expect  7
# 900 :  we observe  8 , and we expect  8
# 901 :  we observe  1 , and we expect  1
# 902 :  we observe  4 , and we expect  4
# 903 :  we observe  4 , and we expect  4
# 904 :  we observe  6 , and we expect  6
# 905 :  we observe  0 , and we expect  0
# 906 :  we observe  2 , and we expect  2
# 907 :  we observe  9 , and we expect  9
# 908 :  we observe  1 , and we expect  1
# 909 :  we observe  4 , and we expect  4
# 910 :  we observe  7 , and we expect  7
# 911 :  we observe  4 , and we expect  4
# 912 :  we observe  7 , and we expect  7
# 913 :  we observe  3 , and we expect  3
# 914 :  we observe  9 , and we expect  9
# 915 :  we observe  8 , and we expect  8
# 916 :  we observe  8 , and we expect  8
# 917 :  we observe  4 , and we expect  4
# 918 :  we observe  7 , and we expect  7
# 919 :  we observe  1 , and we expect  1
# 920 :  we observe  2 , and we expect  2
# 921 :  we observe  1 , and we expect  1
# 922 :  we observe  2 , and we expect  2
# 923 :  we observe  2 , and we expect  2
# 924 :  we observe  3 , and we expect  3
# 925 :  we observe  2 , and we expect  2
# 926 :  we observe  3 , and we expect  3
# 927 :  we observe  2 , and we expect  2
# 928 :  we observe  3 , and we expect  3
# 929 :  we observe  9 , and we expect  9
# 930 :  we observe  1 , and we expect  1
# 931 :  we observe  7 , and we expect  7
# 932 :  we observe  4 , and we expect  4
# 933 :  we observe  0 , and we expect  0
# 934 :  we observe  3 , and we expect  3
# 935 :  we observe  5 , and we expect  5
# 936 :  we observe  5 , and we expect  5
# 937 :  we observe  8 , and we expect  8
# 938 :  we observe  6 , and we expect  6
# 939 :  we observe  5 , and we expect  3
# 940 :  we observe  0 , and we expect  2
# 941 :  we observe  6 , and we expect  6
# 942 :  we observe  7 , and we expect  7
# 943 :  we observe  6 , and we expect  6
# 944 :  we observe  6 , and we expect  6
# 945 :  we observe  3 , and we expect  3
# 946 :  we observe  2 , and we expect  2
# 947 :  we observe  7 , and we expect  7
# 948 :  we observe  9 , and we expect  8
# 949 :  we observe  1 , and we expect  1
# 950 :  we observe  1 , and we expect  1
# 951 :  we observe  7 , and we expect  7
# 952 :  we observe  5 , and we expect  5
# 953 :  we observe  6 , and we expect  6
# 954 :  we observe  4 , and we expect  4
# 955 :  we observe  9 , and we expect  9
# 956 :  we observe  5 , and we expect  5
# 957 :  we observe  1 , and we expect  1
# 958 :  we observe  3 , and we expect  3
# 959 :  we observe  3 , and we expect  3
# 960 :  we observe  4 , and we expect  4
# 961 :  we observe  7 , and we expect  7
# 962 :  we observe  8 , and we expect  8
# 963 :  we observe  9 , and we expect  9
# 964 :  we observe  1 , and we expect  1
# 965 :  we observe  1 , and we expect  1
# 966 :  we observe  0 , and we expect  6
# 967 :  we observe  9 , and we expect  9
# 968 :  we observe  1 , and we expect  1
# 969 :  we observe  4 , and we expect  4
# 970 :  we observe  4 , and we expect  4
# 971 :  we observe  5 , and we expect  5
# 972 :  we observe  4 , and we expect  4
# 973 :  we observe  0 , and we expect  0
# 974 :  we observe  6 , and we expect  6
# 975 :  we observe  2 , and we expect  2
# 976 :  we observe  2 , and we expect  2
# 977 :  we observe  3 , and we expect  3
# 978 :  we observe  1 , and we expect  1
# 979 :  we observe  5 , and we expect  5
# 980 :  we observe  1 , and we expect  1
# 981 :  we observe  2 , and we expect  2
# 982 :  we observe  0 , and we expect  0
# 983 :  we observe  3 , and we expect  3
# 984 :  we observe  8 , and we expect  8
# 985 :  we observe  1 , and we expect  1
# 986 :  we observe  2 , and we expect  2
# 987 :  we observe  6 , and we expect  6
# 988 :  we observe  7 , and we expect  7
# 989 :  we observe  1 , and we expect  1
# 990 :  we observe  6 , and we expect  6
# 991 :  we observe  2 , and we expect  2
# 992 :  we observe  3 , and we expect  3
# 993 :  we observe  9 , and we expect  9
# 994 :  we observe  0 , and we expect  0
# 995 :  we observe  1 , and we expect  1
# 996 :  we observe  2 , and we expect  2
# 997 :  we observe  2 , and we expect  2
# 998 :  we observe  0 , and we expect  0
# 999 :  we observe  8 , and we expect  8
# 1000 :  we observe  9 , and we expect  9
# 1001 :  we observe  9 , and we expect  9
# 1002 :  we observe  0 , and we expect  0
# 1003 :  we observe  2 , and we expect  2
# 1004 :  we observe  5 , and we expect  5
# 1005 :  we observe  1 , and we expect  1
# 1006 :  we observe  9 , and we expect  9
# 1007 :  we observe  7 , and we expect  7
# 1008 :  we observe  8 , and we expect  8
# 1009 :  we observe  1 , and we expect  1
# 1010 :  we observe  0 , and we expect  0
# 1011 :  we observe  4 , and we expect  4
# 1012 :  we observe  1 , and we expect  1
# 1013 :  we observe  7 , and we expect  7
# 1014 :  we observe  9 , and we expect  9
# 1015 :  we observe  5 , and we expect  6
# 1016 :  we observe  4 , and we expect  4
# 1017 :  we observe  2 , and we expect  2
# 1018 :  we observe  6 , and we expect  6
# 1019 :  we observe  8 , and we expect  8
# 1020 :  we observe  1 , and we expect  1
# 1021 :  we observe  3 , and we expect  3
# 1022 :  we observe  7 , and we expect  7
# 1023 :  we observe  5 , and we expect  5
# 1024 :  we observe  4 , and we expect  4
# 1025 :  we observe  4 , and we expect  4
# 1026 :  we observe  1 , and we expect  1
# 1027 :  we observe  8 , and we expect  8
# 1028 :  we observe  1 , and we expect  1
# 1029 :  we observe  3 , and we expect  3
# 1030 :  we observe  8 , and we expect  8
# 1031 :  we observe  1 , and we expect  1
# 1032 :  we observe  2 , and we expect  2
# 1033 :  we observe  5 , and we expect  5
# 1034 :  we observe  8 , and we expect  8
# 1035 :  we observe  0 , and we expect  0
# 1036 :  we observe  6 , and we expect  6
# 1037 :  we observe  2 , and we expect  2
# 1038 :  we observe  1 , and we expect  1
# 1039 :  we observe  1 , and we expect  1
# 1040 :  we observe  1 , and we expect  7
# 1041 :  we observe  1 , and we expect  1
# 1042 :  we observe  5 , and we expect  5
# 1043 :  we observe  3 , and we expect  3
# 1044 :  we observe  4 , and we expect  4
# 1045 :  we observe  8 , and we expect  6
# 1046 :  we observe  9 , and we expect  9
# 1047 :  we observe  5 , and we expect  5
# 1048 :  we observe  0 , and we expect  0
# 1049 :  we observe  9 , and we expect  9
# 1050 :  we observe  2 , and we expect  2
# 1051 :  we observe  2 , and we expect  2
# 1052 :  we observe  4 , and we expect  4
# 1053 :  we observe  8 , and we expect  8
# 1054 :  we observe  2 , and we expect  2
# 1055 :  we observe  1 , and we expect  1
# 1056 :  we observe  7 , and we expect  7
# 1057 :  we observe  2 , and we expect  2
# 1058 :  we observe  4 , and we expect  4
# 1059 :  we observe  9 , and we expect  9
# 1060 :  we observe  4 , and we expect  4
# 1061 :  we observe  4 , and we expect  4
# 1062 :  we observe  0 , and we expect  0
# 1063 :  we observe  3 , and we expect  3
# 1064 :  we observe  9 , and we expect  9
# 1065 :  we observe  2 , and we expect  2
# 1066 :  we observe  2 , and we expect  2
# 1067 :  we observe  3 , and we expect  3
# 1068 :  we observe  3 , and we expect  3
# 1069 :  we observe  8 , and we expect  8
# 1070 :  we observe  3 , and we expect  3
# 1071 :  we observe  5 , and we expect  5
# 1072 :  we observe  7 , and we expect  7
# 1073 :  we observe  3 , and we expect  3
# 1074 :  we observe  5 , and we expect  5
# 1075 :  we observe  8 , and we expect  8
# 1076 :  we observe  1 , and we expect  1
# 1077 :  we observe  2 , and we expect  2
# 1078 :  we observe  4 , and we expect  4
# 1079 :  we observe  4 , and we expect  4
# 1080 :  we observe  6 , and we expect  6
# 1081 :  we observe  4 , and we expect  4
# 1082 :  we observe  9 , and we expect  9
# 1083 :  we observe  5 , and we expect  5
# 1084 :  we observe  1 , and we expect  1
# 1085 :  we observe  0 , and we expect  0
# 1086 :  we observe  6 , and we expect  6
# 1087 :  we observe  9 , and we expect  9
# 1088 :  we observe  5 , and we expect  5
# 1089 :  we observe  9 , and we expect  9
# 1090 :  we observe  5 , and we expect  5
# 1091 :  we observe  9 , and we expect  9
# 1092 :  we observe  7 , and we expect  7
# 1093 :  we observe  3 , and we expect  3
# 1094 :  we observe  8 , and we expect  8
# 1095 :  we observe  0 , and we expect  0
# 1096 :  we observe  3 , and we expect  3
# 1097 :  we observe  7 , and we expect  7
# 1098 :  we observe  1 , and we expect  1
# 1099 :  we observe  3 , and we expect  3
# 1100 :  we observe  6 , and we expect  6
# 1101 :  we observe  7 , and we expect  7
# 1102 :  we observe  8 , and we expect  8
# 1103 :  we observe  5 , and we expect  5
# 1104 :  we observe  9 , and we expect  9
# 1105 :  we observe  7 , and we expect  7
# 1106 :  we observe  9 , and we expect  9
# 1107 :  we observe  6 , and we expect  6
# 1108 :  we observe  9 , and we expect  9
# 1109 :  we observe  6 , and we expect  6
# 1110 :  we observe  3 , and we expect  3
# 1111 :  we observe  7 , and we expect  7
# 1112 :  we observe  4 , and we expect  4
# 1113 :  we observe  6 , and we expect  4
# 1114 :  we observe  5 , and we expect  5
# 1115 :  we observe  3 , and we expect  3
# 1116 :  we observe  5 , and we expect  5
# 1117 :  we observe  4 , and we expect  4
# 1118 :  we observe  7 , and we expect  7
# 1119 :  we observe  8 , and we expect  8
# 1120 :  we observe  8 , and we expect  7
# 1121 :  we observe  8 , and we expect  8
# 1122 :  we observe  0 , and we expect  0
# 1123 :  we observe  7 , and we expect  7
# 1124 :  we observe  6 , and we expect  6
# 1125 :  we observe  8 , and we expect  8
# 1126 :  we observe  8 , and we expect  8
# 1127 :  we observe  7 , and we expect  7
# 1128 :  we observe  3 , and we expect  3
# 1129 :  we observe  2 , and we expect  3
# 1130 :  we observe  1 , and we expect  1
# 1131 :  we observe  9 , and we expect  9
# 1132 :  we observe  5 , and we expect  5
# 1133 :  we observe  2 , and we expect  2
# 1134 :  we observe  7 , and we expect  7
# 1135 :  we observe  3 , and we expect  3
# 1136 :  we observe  5 , and we expect  5
# 1137 :  we observe  1 , and we expect  1
# 1138 :  we observe  1 , and we expect  1
# 1139 :  we observe  2 , and we expect  2
# 1140 :  we observe  1 , and we expect  1
# 1141 :  we observe  4 , and we expect  4
# 1142 :  we observe  7 , and we expect  7
# 1143 :  we observe  4 , and we expect  4
# 1144 :  we observe  7 , and we expect  7
# 1145 :  we observe  5 , and we expect  5
# 1146 :  we observe  4 , and we expect  4
# 1147 :  we observe  5 , and we expect  5
# 1148 :  we observe  4 , and we expect  4
# 1149 :  we observe  0 , and we expect  0
# 1150 :  we observe  8 , and we expect  8
# 1151 :  we observe  3 , and we expect  3
# 1152 :  we observe  6 , and we expect  6
# 1153 :  we observe  9 , and we expect  9
# 1154 :  we observe  6 , and we expect  6
# 1155 :  we observe  0 , and we expect  0
# 1156 :  we observe  2 , and we expect  2
# 1157 :  we observe  7 , and we expect  7
# 1158 :  we observe  4 , and we expect  4
# 1159 :  we observe  4 , and we expect  4
# 1160 :  we observe  4 , and we expect  4
# 1161 :  we observe  4 , and we expect  4
# 1162 :  we observe  6 , and we expect  6
# 1163 :  we observe  6 , and we expect  6
# 1164 :  we observe  4 , and we expect  4
# 1165 :  we observe  7 , and we expect  7
# 1166 :  we observe  9 , and we expect  9
# 1167 :  we observe  3 , and we expect  3
# 1168 :  we observe  4 , and we expect  4
# 1169 :  we observe  5 , and we expect  5
# 1170 :  we observe  5 , and we expect  5
# 1171 :  we observe  8 , and we expect  8
# 1172 :  we observe  7 , and we expect  7
# 1173 :  we observe  3 , and we expect  3
# 1174 :  we observe  7 , and we expect  7
# 1175 :  we observe  2 , and we expect  2
# 1176 :  we observe  7 , and we expect  7
# 1177 :  we observe  0 , and we expect  0
# 1178 :  we observe  2 , and we expect  2
# 1179 :  we observe  0 , and we expect  4
# 1180 :  we observe  1 , and we expect  1
# 1181 :  we observe  1 , and we expect  1
# 1182 :  we observe  1 , and we expect  6
# 1183 :  we observe  8 , and we expect  6
# 1184 :  we observe  9 , and we expect  9
# 1185 :  we observe  2 , and we expect  2
# 1186 :  we observe  8 , and we expect  8
# 1187 :  we observe  7 , and we expect  7
# 1188 :  we observe  2 , and we expect  2
# 1189 :  we observe  0 , and we expect  0
# 1190 :  we observe  1 , and we expect  1
# 1191 :  we observe  5 , and we expect  5
# 1192 :  we observe  0 , and we expect  0
# 1193 :  we observe  4 , and we expect  9
# 1194 :  we observe  1 , and we expect  1
# 1195 :  we observe  8 , and we expect  7
# 1196 :  we observe  0 , and we expect  0
# 1197 :  we observe  6 , and we expect  6
# ...
# 9613 :  we observe  1 , and we expect  1
# 9614 :  we observe  2 , and we expect  2
# 9615 :  we observe  3 , and we expect  3
# 9616 :  we observe  4 , and we expect  4
# 9617 :  we observe  5 , and we expect  5
# 9618 :  we observe  6 , and we expect  6
# 9619 :  we observe  7 , and we expect  7
# 9620 :  we observe  8 , and we expect  8
# 9621 :  we observe  9 , and we expect  9
# 9622 :  we observe  0 , and we expect  0
# 9623 :  we observe  1 , and we expect  1
# 9624 :  we observe  2 , and we expect  2
# 9625 :  we observe  3 , and we expect  3
# 9626 :  we observe  4 , and we expect  4
# 9627 :  we observe  5 , and we expect  5
# 9628 :  we observe  6 , and we expect  6
# 9629 :  we observe  7 , and we expect  7
# 9630 :  we observe  8 , and we expect  8
# 9631 :  we observe  8 , and we expect  8
# 9632 :  we observe  0 , and we expect  0
# 9633 :  we observe  6 , and we expect  6
# 9634 :  we observe  0 , and we expect  0
# 9635 :  we observe  1 , and we expect  0
# 9636 :  we observe  2 , and we expect  2
# 9637 :  we observe  3 , and we expect  3
# 9638 :  we observe  7 , and we expect  7
# 9639 :  we observe  9 , and we expect  9
# 9640 :  we observe  4 , and we expect  4
# 9641 :  we observe  7 , and we expect  7
# 9642 :  we observe  1 , and we expect  1
# 9643 :  we observe  9 , and we expect  9
# 9644 :  we observe  1 , and we expect  1
# 9645 :  we observe  7 , and we expect  7
# 9646 :  we observe  1 , and we expect  1
# 9647 :  we observe  4 , and we expect  4
# 9648 :  we observe  0 , and we expect  0
# 9649 :  we observe  0 , and we expect  0
# 9650 :  we observe  1 , and we expect  1
# 9651 :  we observe  7 , and we expect  7
# 9652 :  we observe  5 , and we expect  5
# 9653 :  we observe  7 , and we expect  7
# 9654 :  we observe  1 , and we expect  1
# 9655 :  we observe  3 , and we expect  3
# 9656 :  we observe  3 , and we expect  3
# 9657 :  we observe  3 , and we expect  3
# 9658 :  we observe  1 , and we expect  1
# 9659 :  we observe  6 , and we expect  6
# 9660 :  we observe  9 , and we expect  9
# 9661 :  we observe  7 , and we expect  7
# 9662 :  we observe  1 , and we expect  1
# 9663 :  we observe  3 , and we expect  3
# 9664 :  we observe  0 , and we expect  0
# 9665 :  we observe  7 , and we expect  2
# 9666 :  we observe  6 , and we expect  6
# 9667 :  we observe  0 , and we expect  0
# 9668 :  we observe  8 , and we expect  8
# 9669 :  we observe  9 , and we expect  9
# 9670 :  we observe  4 , and we expect  4
# 9671 :  we observe  3 , and we expect  3
# 9672 :  we observe  5 , and we expect  5
# 9673 :  we observe  4 , and we expect  4
# 9674 :  we observe  8 , and we expect  8
# 9675 :  we observe  1 , and we expect  1
# 9676 :  we observe  5 , and we expect  5
# 9677 :  we observe  9 , and we expect  9
# 9678 :  we observe  0 , and we expect  0
# 9679 :  we observe  6 , and we expect  6
# 9680 :  we observe  6 , and we expect  6
# 9681 :  we observe  3 , and we expect  3
# 9682 :  we observe  8 , and we expect  8
# 9683 :  we observe  1 , and we expect  1
# 9684 :  we observe  4 , and we expect  4
# 9685 :  we observe  7 , and we expect  7
# 9686 :  we observe  5 , and we expect  5
# 9687 :  we observe  2 , and we expect  2
# 9688 :  we observe  0 , and we expect  0
# 9689 :  we observe  0 , and we expect  0
# 9690 :  we observe  1 , and we expect  1
# 9691 :  we observe  7 , and we expect  7
# 9692 :  we observe  8 , and we expect  8
# 9693 :  we observe  7 , and we expect  9
# 9694 :  we observe  6 , and we expect  6
# 9695 :  we observe  8 , and we expect  8
# 9696 :  we observe  8 , and we expect  8
# 9697 :  we observe  2 , and we expect  2
# 9698 :  we observe  3 , and we expect  3
# 9699 :  we observe  6 , and we expect  6
# 9700 :  we observe  1 , and we expect  1
# 9701 :  we observe  2 , and we expect  2
# 9702 :  we observe  9 , and we expect  9
# 9703 :  we observe  5 , and we expect  5
# 9704 :  we observe  2 , and we expect  2
# 9705 :  we observe  0 , and we expect  0
# 9706 :  we observe  1 , and we expect  1
# 9707 :  we observe  2 , and we expect  2
# 9708 :  we observe  3 , and we expect  3
# 9709 :  we observe  4 , and we expect  4
# 9710 :  we observe  5 , and we expect  5
# 9711 :  we observe  6 , and we expect  6
# 9712 :  we observe  7 , and we expect  7
# 9713 :  we observe  8 , and we expect  8
# 9714 :  we observe  9 , and we expect  9
# 9715 :  we observe  0 , and we expect  0
# 9716 :  we observe  1 , and we expect  1
# 9717 :  we observe  5 , and we expect  2
# 9718 :  we observe  3 , and we expect  3
# 9719 :  we observe  4 , and we expect  4
# 9720 :  we observe  5 , and we expect  5
# 9721 :  we observe  6 , and we expect  6
# 9722 :  we observe  7 , and we expect  7
# 9723 :  we observe  8 , and we expect  8
# 9724 :  we observe  9 , and we expect  9
# 9725 :  we observe  0 , and we expect  0
# 9726 :  we observe  1 , and we expect  1
# 9727 :  we observe  2 , and we expect  2
# 9728 :  we observe  3 , and we expect  3
# 9729 :  we observe  4 , and we expect  4
# 9730 :  we observe  6 , and we expect  5
# 9731 :  we observe  6 , and we expect  6
# 9732 :  we observe  7 , and we expect  7
# 9733 :  we observe  8 , and we expect  8
# 9734 :  we observe  9 , and we expect  9
# 9735 :  we observe  7 , and we expect  7
# 9736 :  we observe  4 , and we expect  4
# 9737 :  we observe  6 , and we expect  6
# 9738 :  we observe  1 , and we expect  1
# 9739 :  we observe  4 , and we expect  4
# 9740 :  we observe  0 , and we expect  0
# 9741 :  we observe  9 , and we expect  9
# 9742 :  we observe  9 , and we expect  9
# 9743 :  we observe  3 , and we expect  3
# 9744 :  we observe  7 , and we expect  7
# 9745 :  we observe  8 , and we expect  8
# 9746 :  we observe  0 , and we expect  4
# 9747 :  we observe  7 , and we expect  7
# 9748 :  we observe  5 , and we expect  5
# 9749 :  we observe  8 , and we expect  8
# 9750 :  we observe  5 , and we expect  5
# 9751 :  we observe  3 , and we expect  3
# 9752 :  we observe  2 , and we expect  2
# 9753 :  we observe  2 , and we expect  2
# 9754 :  we observe  0 , and we expect  0
# 9755 :  we observe  5 , and we expect  5
# 9756 :  we observe  8 , and we expect  8
# 9757 :  we observe  6 , and we expect  6
# 9758 :  we observe  0 , and we expect  0
# 9759 :  we observe  3 , and we expect  3
# 9760 :  we observe  8 , and we expect  8
# 9761 :  we observe  1 , and we expect  1
# 9762 :  we observe  0 , and we expect  0
# 9763 :  we observe  3 , and we expect  3
# 9764 :  we observe  0 , and we expect  0
# 9765 :  we observe  9 , and we expect  4
# 9766 :  we observe  7 , and we expect  7
# 9767 :  we observe  4 , and we expect  4
# 9768 :  we observe  9 , and we expect  9
# 9769 :  we observe  2 , and we expect  2
# 9770 :  we observe  9 , and we expect  9
# 9771 :  we observe  0 , and we expect  5
# 9772 :  we observe  7 , and we expect  7
# 9773 :  we observe  1 , and we expect  1
# 9774 :  we observe  7 , and we expect  7
# 9775 :  we observe  1 , and we expect  1
# 9776 :  we observe  6 , and we expect  6
# 9777 :  we observe  6 , and we expect  6
# 9778 :  we observe  5 , and we expect  5
# 9779 :  we observe  6 , and we expect  6
# 9780 :  we observe  0 , and we expect  2
# 9781 :  we observe  8 , and we expect  8
# 9782 :  we observe  7 , and we expect  7
# 9783 :  we observe  6 , and we expect  6
# 9784 :  we observe  4 , and we expect  4
# 9785 :  we observe  9 , and we expect  9
# 9786 :  we observe  9 , and we expect  9
# 9787 :  we observe  5 , and we expect  5
# 9788 :  we observe  3 , and we expect  3
# 9789 :  we observe  7 , and we expect  7
# 9790 :  we observe  4 , and we expect  4
# 9791 :  we observe  3 , and we expect  3
# 9792 :  we observe  0 , and we expect  0
# 9793 :  we observe  9 , and we expect  4
# 9794 :  we observe  6 , and we expect  6
# 9795 :  we observe  6 , and we expect  6
# 9796 :  we observe  1 , and we expect  1
# 9797 :  we observe  1 , and we expect  1
# 9798 :  we observe  3 , and we expect  3
# 9799 :  we observe  2 , and we expect  2
# 9800 :  we observe  1 , and we expect  1
# 9801 :  we observe  0 , and we expect  0
# 9802 :  we observe  0 , and we expect  0
# 9803 :  we observe  1 , and we expect  1
# 9804 :  we observe  2 , and we expect  2
# 9805 :  we observe  3 , and we expect  3
# 9806 :  we observe  4 , and we expect  4
# 9807 :  we observe  7 , and we expect  7
# 9808 :  we observe  8 , and we expect  8
# 9809 :  we observe  9 , and we expect  9
# 9810 :  we observe  0 , and we expect  0
# 9811 :  we observe  1 , and we expect  1
# 9812 :  we observe  2 , and we expect  2
# 9813 :  we observe  3 , and we expect  3
# 9814 :  we observe  4 , and we expect  4
# 9815 :  we observe  5 , and we expect  5
# 9816 :  we observe  6 , and we expect  6
# 9817 :  we observe  7 , and we expect  7
# 9818 :  we observe  8 , and we expect  8
# 9819 :  we observe  0 , and we expect  0
# 9820 :  we observe  1 , and we expect  1
# 9821 :  we observe  2 , and we expect  2
# 9822 :  we observe  3 , and we expect  3
# 9823 :  we observe  4 , and we expect  4
# 9824 :  we observe  7 , and we expect  7
# 9825 :  we observe  8 , and we expect  8
# 9826 :  we observe  9 , and we expect  9
# 9827 :  we observe  0 , and we expect  0
# 9828 :  we observe  8 , and we expect  8
# 9829 :  we observe  3 , and we expect  3
# 9830 :  we observe  9 , and we expect  9
# 9831 :  we observe  5 , and we expect  5
# 9832 :  we observe  5 , and we expect  5
# 9833 :  we observe  2 , and we expect  2
# 9834 :  we observe  6 , and we expect  6
# 9835 :  we observe  8 , and we expect  8
# 9836 :  we observe  4 , and we expect  4
# 9837 :  we observe  1 , and we expect  1
# 9838 :  we observe  7 , and we expect  7
# 9839 :  we observe  1 , and we expect  1
# 9840 :  we observe  7 , and we expect  2
# 9841 :  we observe  3 , and we expect  3
# 9842 :  we observe  5 , and we expect  5
# 9843 :  we observe  6 , and we expect  6
# 9844 :  we observe  9 , and we expect  9
# 9845 :  we observe  1 , and we expect  1
# 9846 :  we observe  1 , and we expect  1
# 9847 :  we observe  1 , and we expect  1
# 9848 :  we observe  2 , and we expect  2
# 9849 :  we observe  1 , and we expect  1
# 9850 :  we observe  2 , and we expect  2
# 9851 :  we observe  0 , and we expect  0
# 9852 :  we observe  7 , and we expect  7
# 9853 :  we observe  7 , and we expect  7
# 9854 :  we observe  5 , and we expect  5
# 9855 :  we observe  8 , and we expect  8
# 9856 :  we observe  2 , and we expect  2
# 9857 :  we observe  9 , and we expect  9
# 9858 :  we observe  8 , and we expect  8
# 9859 :  we observe  6 , and we expect  6
# 9860 :  we observe  7 , and we expect  7
# 9861 :  we observe  3 , and we expect  3
# 9862 :  we observe  4 , and we expect  4
# 9863 :  we observe  6 , and we expect  6
# 9864 :  we observe  8 , and we expect  8
# 9865 :  we observe  7 , and we expect  7
# 9866 :  we observe  0 , and we expect  0
# 9867 :  we observe  4 , and we expect  4
# 9868 :  we observe  2 , and we expect  2
# 9869 :  we observe  7 , and we expect  7
# 9870 :  we observe  7 , and we expect  7
# 9871 :  we observe  5 , and we expect  5
# 9872 :  we observe  4 , and we expect  4
# 9873 :  we observe  3 , and we expect  3
# 9874 :  we observe  4 , and we expect  4
# 9875 :  we observe  2 , and we expect  2
# 9876 :  we observe  8 , and we expect  8
# 9877 :  we observe  1 , and we expect  1
# 9878 :  we observe  5 , and we expect  5
# 9879 :  we observe  1 , and we expect  1
# 9880 :  we observe  0 , and we expect  0
# 9881 :  we observe  2 , and we expect  2
# 9882 :  we observe  3 , and we expect  3
# 9883 :  we observe  3 , and we expect  3
# 9884 :  we observe  5 , and we expect  5
# 9885 :  we observe  7 , and we expect  7
# 9886 :  we observe  0 , and we expect  0
# 9887 :  we observe  6 , and we expect  6
# 9888 :  we observe  8 , and we expect  8
# 9889 :  we observe  6 , and we expect  6
# 9890 :  we observe  3 , and we expect  3
# 9891 :  we observe  9 , and we expect  9
# 9892 :  we observe  9 , and we expect  9
# 9893 :  we observe  8 , and we expect  8
# 9894 :  we observe  2 , and we expect  2
# 9895 :  we observe  7 , and we expect  7
# 9896 :  we observe  7 , and we expect  7
# 9897 :  we observe  1 , and we expect  1
# 9898 :  we observe  0 , and we expect  0
# 9899 :  we observe  1 , and we expect  1
# 9900 :  we observe  7 , and we expect  7
# 9901 :  we observe  8 , and we expect  8
# 9902 :  we observe  9 , and we expect  9
# 9903 :  we observe  0 , and we expect  0
# 9904 :  we observe  1 , and we expect  1
# 9905 :  we observe  2 , and we expect  2
# 9906 :  we observe  3 , and we expect  3
# 9907 :  we observe  4 , and we expect  4
# 9908 :  we observe  5 , and we expect  5
# 9909 :  we observe  6 , and we expect  6
# 9910 :  we observe  7 , and we expect  7
# 9911 :  we observe  8 , and we expect  8
# 9912 :  we observe  0 , and we expect  0
# 9913 :  we observe  1 , and we expect  1
# 9914 :  we observe  2 , and we expect  2
# 9915 :  we observe  3 , and we expect  3
# 9916 :  we observe  4 , and we expect  4
# 9917 :  we observe  7 , and we expect  7
# 9918 :  we observe  8 , and we expect  8
# 9919 :  we observe  9 , and we expect  9
# 9920 :  we observe  7 , and we expect  7
# 9921 :  we observe  8 , and we expect  8
# 9922 :  we observe  6 , and we expect  6
# 9923 :  we observe  4 , and we expect  4
# 9924 :  we observe  1 , and we expect  1
# 9925 :  we observe  9 , and we expect  9
# 9926 :  we observe  3 , and we expect  3
# 9927 :  we observe  8 , and we expect  8
# 9928 :  we observe  4 , and we expect  4
# 9929 :  we observe  4 , and we expect  4
# 9930 :  we observe  7 , and we expect  7
# 9931 :  we observe  0 , and we expect  0
# 9932 :  we observe  1 , and we expect  1
# 9933 :  we observe  9 , and we expect  9
# 9934 :  we observe  2 , and we expect  2
# 9935 :  we observe  8 , and we expect  8
# 9936 :  we observe  7 , and we expect  7
# 9937 :  we observe  8 , and we expect  8
# 9938 :  we observe  2 , and we expect  2
# 9939 :  we observe  6 , and we expect  6
# 9940 :  we observe  0 , and we expect  0
# 9941 :  we observe  6 , and we expect  6
# 9942 :  we observe  5 , and we expect  5
# 9943 :  we observe  3 , and we expect  3
# 9944 :  we observe  3 , and we expect  3
# 9945 :  we observe  2 , and we expect  3
# 9946 :  we observe  9 , and we expect  9
# 9947 :  we observe  1 , and we expect  1
# 9948 :  we observe  4 , and we expect  4
# 9949 :  we observe  0 , and we expect  0
# 9950 :  we observe  6 , and we expect  6
# 9951 :  we observe  1 , and we expect  1
# 9952 :  we observe  0 , and we expect  0
# 9953 :  we observe  0 , and we expect  0
# 9954 :  we observe  6 , and we expect  6
# 9955 :  we observe  2 , and we expect  2
# 9956 :  we observe  1 , and we expect  1
# 9957 :  we observe  1 , and we expect  1
# 9958 :  we observe  7 , and we expect  7
# 9959 :  we observe  7 , and we expect  7
# 9960 :  we observe  8 , and we expect  8
# 9961 :  we observe  4 , and we expect  4
# 9962 :  we observe  6 , and we expect  6
# 9963 :  we observe  0 , and we expect  0
# 9964 :  we observe  7 , and we expect  7
# 9965 :  we observe  0 , and we expect  0
# 9966 :  we observe  3 , and we expect  3
# 9967 :  we observe  6 , and we expect  6
# 9968 :  we observe  8 , and we expect  8
# 9969 :  we observe  7 , and we expect  7
# 9970 :  we observe  1 , and we expect  1
# 9971 :  we observe  5 , and we expect  5
# 9972 :  we observe  2 , and we expect  2
# 9973 :  we observe  4 , and we expect  4
# 9974 :  we observe  9 , and we expect  9
# 9975 :  we observe  4 , and we expect  4
# 9976 :  we observe  3 , and we expect  3
# 9977 :  we observe  6 , and we expect  6
# 9978 :  we observe  4 , and we expect  4
# 9979 :  we observe  1 , and we expect  1
# 9980 :  we observe  7 , and we expect  7
# 9981 :  we observe  2 , and we expect  2
# 9982 :  we observe  6 , and we expect  6
# 9983 :  we observe  5 , and we expect  5
# 9984 :  we observe  0 , and we expect  0
# 9985 :  we observe  1 , and we expect  1
# 9986 :  we observe  2 , and we expect  2
# 9987 :  we observe  3 , and we expect  3
# 9988 :  we observe  4 , and we expect  4
# 9989 :  we observe  5 , and we expect  5
# 9990 :  we observe  6 , and we expect  6
# 9991 :  we observe  7 , and we expect  7
# 9992 :  we observe  8 , and we expect  8
# 9993 :  we observe  9 , and we expect  9
# 9994 :  we observe  0 , and we expect  0
# 9995 :  we observe  1 , and we expect  1
# 9996 :  we observe  2 , and we expect  2
# 9997 :  we observe  3 , and we expect  3
# 9998 :  we observe  4 , and we expect  4
# 9999 :  we observe  5 , and we expect  5
# 10000 :  we observe  6 , and we expect  6
# total:  10000  correct:  9761  percentage:  97.61 %
